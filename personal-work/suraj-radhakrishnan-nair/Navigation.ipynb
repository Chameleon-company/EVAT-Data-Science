# %%
# !pip install googlemaps folium shapely pandas
# Out:
# Collecting googlemaps
#   Downloading googlemaps-4.10.0.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.17.0)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (2.0.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: requests<3.0,>=2.20.0 in /usr/local/lib/python3.10/dist-packages (from googlemaps) (2.32.3)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.26.4)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from folium) (2024.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2024.7.4)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (setup.py) ... done
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40716 sha256=277fd5d2ae34175396e88d8da1e35a53ea24612e55909f1f9e0970e48beac215
#   Stored in directory: /root/.cache/pip/wheels/17/f8/79/999d5d37118fd35d7219ef57933eb9d09886c4c4503a800f84
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.10.0

# %%
import googlemaps
from shapely.geometry import Point, LineString
import folium
from googlemaps.convert import decode_polyline
import pandas as pd

# %%
gmaps = googlemaps.Client(key='AIzaSyA0Tje6iD8W3PKTMxH7au2NlZAWr0y1xjw')

# %%
geelong = "Geelong, VIC, Australia"
melbourne = "Melbourne, VIC, Australia"

# Request directions via driving
directions_result = gmaps.directions(geelong, melbourne, mode="driving")

# Extract the polyline (route) from the response
polyline = directions_result[0]['overview_polyline']['points']

# %%
route_coords = decode_polyline(polyline)
route_line = LineString([(point['lat'], point['lng']) for point in route_coords])

# %%
buffer_distance = 0.01  # Adjust based on the desired buffer size
buffered_route = route_line.buffer(buffer_distance)

# %%
ev_charging_stations = []

for coord in route_coords:
    nearby_stations = gmaps.places_nearby(location=(coord['lat'], coord['lng']),
                                          radius=buffer_distance * 100000,  # Convert to meters
                                          type='charging_station')
    ev_charging_stations.extend(nearby_stations['results'])

# Remove duplicates by place_id
ev_charging_stations = {station['place_id']: station for station in ev_charging_stations}.values()

# %%
gmaps = googlemaps.Client(key='AIzaSyA0Tje6iD8W3PKTMxH7au2NlZAWr0y1xjw')

# Simple geocoding request to test the API key
geocode_result = gmaps.geocode('Melbourne, VIC, Australia')

print(geocode_result)
# Out:
# [{'address_components': [{'long_name': 'Melbourne', 'short_name': 'Melbourne', 'types': ['colloquial_area', 'locality', 'political']}, {'long_name': 'Victoria', 'short_name': 'VIC', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Australia', 'short_name': 'AU', 'types': ['country', 'political']}], 'formatted_address': 'Melbourne VIC, Australia', 'geometry': {'bounds': {'northeast': {'lat': -37.5112737, 'lng': 145.5125288}, 'southwest': {'lat': -38.4338593, 'lng': 144.5937418}}, 'location': {'lat': -37.8136276, 'lng': 144.9630576}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': -37.5112737, 'lng': 145.5125288}, 'southwest': {'lat': -38.4338593, 'lng': 144.5937418}}}, 'place_id': 'ChIJ90260rVG1moRkM2MIXVWBAQ', 'types': ['colloquial_area', 'locality', 'political']}]

# %%
# Testing places_nearby with a fixed location and radius
test_location = (-37.8136276, 144.9630576)  # Melbourne's coordinates
test_radius = 5000  # 5 km

try:
    nearby_stations = gmaps.places_nearby(location=test_location,
                                          radius=test_radius,
                                          type='charging_station')
    print(nearby_stations)
except googlemaps.exceptions.ApiError as e:
    print(f"API Error: {e}")
except Exception as e:
    print(f"Unexpected Error: {e}")
# Out:
# {'html_attributions': [], 'next_page_token': 'AelY_Cuzdz2AEyM1TidSBxjAzMZWzujJo6TEdxhOMeYOlU2PS0DpbnnG0_J14hk1eIPtRF0ttdhNl3YfissbOnfaOTXYtHZRtQw4VgacKSJQ1g2qDFwn7afExkBIxePGIRqiubm64UviyuQ-eHXMsNLHzTT_RKiCoxBf6LDSwM9U_1wm2E0aeoOwshdxk3wDoJzmcQIT40Y_WcL0W4WPAikdtxbAtmv_g6t7BbDtT-GtWbJ9yTxYZt7XPZEdxXL5saKrGOkB_MxvVhLeqRN3n95lBwAdSiT9Y6TpZHAmDS2U7P-tXUQbIkFmSOF46iv
 'scope': 'GOOGLE', 'types': ['lodging', 'point_of_interest', 'establishment'], 'user_ratings_total': 2431, 'vicinity': '270 Collins Street, Melbo ...

# %%
try:
    nearby_stations = gmaps.places_nearby(location=test_location, radius=test_radius)
    print(nearby_stations)
except googlemaps.exceptions.ApiError as e:
    print(f"API Error: {e}")
except Exception as e:
    print(f"Unexpected Error: {e}")
# Out:
# {'html_attributions': [], 'next_page_token': 'AelY_Cv0pewtrc7SlEnwuvOqY7DdDfn0aJlPcpH-eBNgiQLXZTHO1c_ankGggeYkmBkfEB3gKcPoG96t_FiuGtR0DOLGpwRCj8trmzEm3Jw1TJqUgou9sBvgMpzqAIfPCo0aTrOdHQqT7BCy9dVFtJqTZh8JLi6c1D1QNHsEx1Msv6z-hMJZ7RTe6Pf8z3lt54ZN0_St2T2wX0h-g5M10XJFC5wUci4duGs2idAE7qkfK-h6vzp5mRGllmSA2djqWhWsW3oZLbYHaHSSkT0fMLTG4-2jAoQH_qCAQ5izHF-mhfX17oXCPIQL7bghdF0GKw4ykMLM9IPf-LxIQparfBKFbpbOnBmJLYh8eElnhkx41xjm_U3sTHHYkZzPz_dbxuoURlTtFM-I_qpD6Oc42vmQHItenIFXH0jMF1Qy7mg7h3ec', 'results': [{'geometry': {'location': {'lat': -37.8136276, 'lng': 144.9630576}, 'viewport': {'northeast': {'lat': -37.5112736581378, 'lng': 145.512528780816}, 'southwest': {'lat': -38.43385934606901, 'lng': 144.5937417793496}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png', 'icon_background_color': '#7B9EB0', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet', 'name': 'Melbourne', 'photos': [{'height': 2160, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111655350700098310293">Siddhardha Bobba</a>'], 'photo_reference': 'AelY_CvEwUJuN5Wf3tagb3xcLKniEJubXpEuCCpWUGmadz9KkBxtaLdWznMVbyVWoo1lVyLu9-24ibsxbRQ00vsMemqZjnBzfQc_4FJk3lmFsgcKCpJBVM1Lx0eCuZuS9424OXF77M3Z2TQ4F20ytUN4JA-uUPc5JFxAPO5hjBzl3Z981ENo', 'width': 3840}], 'place_id': 'ChIJ90260rVG1moRkM2MIXVWBAQ', 'reference': 'ChIJ90260rVG1moRkM2MIXVWBAQ', 'scope': 'GOOGLE', 'types': ['colloquial_area', 'locality', 'political'], 'vicinity': 'Melbourne'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': -37.8157805, 'lng': 144.9631265}, 'viewport': {'northeast': {'lat': -37.8144480697085, 'lng': 144.9645079302915}, 'southwest': {'lat': -37.8171460302915, 'lng': 144.9618099697085}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png', 'icon_background_color': '#909CE1', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet', 'name': 'Causeway 353 Hotel', 'opening_hours': {'open_now': True}, 'photos': [{'height': 2002, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111610829586975705739">Causeway 353 Hotel</a>'], 'photo_reference': 'AelY_CuYNog-q9SMWVBBoT4j_I1UcN_TKJ8xOMVT4Yl7bemMQSaalHmZVL27Jq-4bS9YUi3q956GgawsP49JVh7QzrPP5D872UDQAAHtapQzV4U8gpOI3T6rP4hTFI-kQeDzXmlnAGyQc-FxLyXdwOwIm3eAZV8nlj-FB0eDpSshABo-xG9G', 'width': 3000}], 'place_id': 'ChIJE1lY77RC1moRQqyQFRPjyl0', 'plus_code': {'compound_code': '5XM7+M7 Melbourne VIC, Australia', 'global_code': '4RJ65XM7+M7'}, 'rating': 4, 'reference': 'ChIJE1lY77RC1moRQqyQFRPjyl0', 'scope': 'GOOGLE', 'types': ['lodging', 'point_of_interest', 'establishment'], 'user_ratings_total': 802, 'vicinity': '353 Little Collins Street, Melbourne'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': -37.8157663, 'lng': 144.9648408}, 'viewport': {'northeast': {'lat': -37.8145090197085, 'lng': 144.9662557802915}, 'southwest': {'lat': -37.8172069802915, 'lng': 144.9635578197085}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png', 'icon_background_color': '#909CE1', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet', 'name': 'Novotel Melbourne on Collins', 'photos': [{'height': 5500, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105084319505053629581">Novotel Melbourne on Collins</a>'], 'photo_reference': 'AelY_Cttg_3GuPpsjOSIWywf340E1GmJ35PO7gRt1SBxrELB8N9YhV2LQ5Q-4yZgNNpj2F1G6EAzd9Qo-ZgPSGw7AZ5IAAPSlYxmLMjVee4lqjkPKuxikldLDtPjUedOUyfJ6FC9D3BgDdLJn4ZTWV2ZgYuriysTrCuwpVv0Hba6ojF4-8Ci', 'width': 3667}], 'place_id': 'ChIJvV3BTrRC1moRdkk9WaX7b8Q', 'plus_code': {'compound_code': '5XM7+MW Melbourne VIC, Australia', 'global_code': '4RJ65XM7+MW'}, 'rating': 4.1, 'reference': 'ChIJvV3BTrRC1moRdkk9WaX7b8Q', 'scope': 'GOOGLE', 'types': ['lodging', 'point_of_interest', 'establishment'], 'user_ratings_total': 2431, 'vicinity': '270 Collins Street, Melbourne'}, {'business_statu ...

# %%
try:
    nearby_stations = gmaps.places_nearby(location=test_location, radius=test_radius, keyword='EV charging')
    print(nearby_stations)
except googlemaps.exceptions.ApiError as e:
    print(f"API Error: {e}")
except Exception as e:
    print(f"Unexpected Error: {e}")
# Out:
# {'html_attributions': [], 'next_page_token': 'AelY_CtDfnr4I2UTM7iBBTYbOMCo23b7PAUQ5LJfVvuQX4bhdJW_INEdhpjGOKgx3LgKwoSXuyVe923yTaI6z8IpFGzIcWSfPm8iDms3p1haNUp96OxqrHyiScbll9w54W4ijnwfGEEIcuuI0B3Y33ouWOaXD0VUAYaV-KGDbSLl8VnMJ-rBTkezB8I2_Hyy1d6L9e3KktQTzUA9L3LHyXeODQFaiu8ED7Y0fLtXZbZriAwwHVq9fTxRig5U3DTiskvBnIIzfnRLl_V4hwNgaZqeoEes6INF5wQ6tneHvIiXTvoQOWziY1WYAJ2kMZPEgpX1E06BTzx1RY7vzzycck37O7CNEA-E7VFbYfhS3Bm7UHJae632le6XwqdQ3MrA4Nlyfd8v9t2UZP0D6JGGRRw-s3D2fER2FjPIK8Ik1DOrx7Z1pRtoQwZh7Qn6qAkp5Q', 'results': [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': -37.8044708, 'lng': 144.9932696}, 'viewport': {'northeast': {'lat': -37.80312432010728, 'lng': 144.9946531798927}, 'southwest': {'lat': -37.80582397989272, 'lng': 144.9919535201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png', 'icon_background_color': '#7B9EB0', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet', 'name': 'Evie Charging Station', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3000, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107803627969816135746">A Google User</a>'], 'photo_reference': 'AelY_Cvuw0VtTcJWOBs_Cpv6_6o__DPGlQCkv1jwPEnFFQLwfBog8o_l0KHS6M2nim2ddGqUjKqZW6u4MtpUORIOd5RiftcWHEFpuRe-CDFNa2drSprmyEVloEf1jTelA2UurWe0Dxe6FsZVgyoTwdAK_PRIkW9BzRCQ7wGiAE3coNUcUPn_', 'width': 4000}], 'place_id': 'ChIJK20XpOJC1moRu6roboUbY-s', 'plus_code': {'compound_code': '5XWV+68 Abbotsford, Victoria, Australia', 'global_code': '4RJ65XWV+68'}, 'rating': 4.9, 'reference': 'ChIJK20XpOJC1moRu6roboUbY-s', 'scope': 'GOOGLE', 'types': ['point_of_interest', 'establishment'], 'user_ratings_total': 7, 'vicinity': '13 Stanton St, Abbotsford'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': -37.8321121, 'lng': 144.9957142}, 'viewport': {'northeast': {'lat': -37.83076717010727, 'lng': 144.9971028798927}, 'southwest': {'lat': -37.83346682989271, 'lng': 144.9944032201072}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png', 'icon_background_color': '#7B9EB0', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet', 'name': 'Tesla Supercharger', 'opening_hours': {'open_now': True}, 'photos': [{'height': 2268, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100713644882654881662">Jason Cartwright</a>'], 'photo_reference': 'AelY_CshtuwYYVupV02nefe5a7fX5I6btSv9qlgRnlb95swI72v9xjkIbI4EmTdU3opdaxN-dlmwyewLdHZIdfwxGDXXMBdPfkL1a5aJhtmPqi5FN6tLfGl1CnsaJXworG0pbni6l2VEEOZfJYWHhQsQWxBB2NdQk_fqUpcFJ_Ho1f35w0-1', 'width': 4032}], 'place_id': 'ChIJ4dCvlY9C1moR2HtYKzTzUD4', 'plus_code': {'compound_code': '5X9W+57 Cremorne, Victoria, Australia', 'global_code': '4RJ65X9W+57'}, 'rating': 4.4, 'reference': 'ChIJ4dCvlY9C1moR2HtYKzTzUD4', 'scope': 'GOOGLE', 'types': ['point_of_interest', 'establishment'], 'user_ratings_total': 80, 'vicinity': '650 Church St, Cremorne'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': -37.7726351, 'lng': 144.9152875}, 'viewport': {'northeast': {'lat': -37.77133517010727, 'lng': 144.9166285798927}, 'southwest': {'lat': -37.77403482989271, 'lng': 144.9139289201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png', 'icon_background_color': '#7B9EB0', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet', 'name': 'Evie Charging Station', 'opening_hours': {'open_now': True}, 'photos': [{'height': 808, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115417320522495844367">Lach Lan</a>'], 'photo_reference': 'AelY_CvD2ibUaIxb2A_b8-hywgBhwIMjCIptQT9-fDbUdc_xPtSkLMc-ECPG7BDW5_0St9yuAqRTCqYb_rqzMbIHDk2y8q90oq30oSKgqqw5MiQIzKZy9tfOYW9-M6oYVGZCiwE2V7DCjbYWggns64d_FA3gXb9m83titIhCa2cGHiIu6ZzE', 'width': 1079}], 'place_id': 'ChIJV3oZcVZc1moRZAClvDlVZVo', 'plus_code': {'compound_code': '6WG8+W4 Ascot V ...

# %%
# If there are more results, retrieve them using the next_page_token
if 'next_page_token' in nearby_stations:
    next_page_token = nearby_stations['next_page_token']
    try:
        more_stations = gmaps.places_nearby(location=test_location,
                                            radius=test_radius,
                                            keyword='EV charging',
                                            page_token=next_page_token)
        print(more_stations)
    except googlemaps.exceptions.ApiError as e:
        print(f"API Error: {e}")
    except Exception as e:
        print(f"Unexpected Error: {e}")
# Out:
# {'html_attributions': [], 'results': [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': -37.825979, 'lng': 144.9492748}, 'viewport': {'northeast': {'lat': -37.82419057010728, 'lng': 144.9508255798927}, 'southwest': {'lat': -37.82689022989272, 'lng': 144.9481259201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png', 'icon_background_color': '#7B9EB0', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet', 'name': 'Chargefox Charging Station', 'opening_hours': {'open_now': False}, 'place_id': 'ChIJAwnXEVhd1moR9e4VKO4cNfI', 'plus_code': {'compound_code': '5WFX+JP South Wharf, Victoria, Australia', 'global_code': '4RJ65WFX+JP'}, 'rating': 0, 'reference': 'ChIJAwnXEVhd1moR9e4VKO4cNfI', 'scope': 'GOOGLE', 'types': ['point_of_interest', 'establishment'], 'user_ratings_total': 0, 'vicinity': 'Level 1/7 Convention Centre Pl, South Wharf'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': -37.8046035, 'lng': 144.9474587}, 'viewport': {'northeast': {'lat': -37.80338237010728, 'lng': 144.9487548798927}, 'southwest': {'lat': -37.80608202989272, 'lng': 144.9460552201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png', 'icon_background_color': '#7B9EB0', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet', 'name': 'Exploren Charging Station', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117385207245403489426">扇山魁斗</a>'], 'photo_reference': 'AelY_CsC0V9hOjDWkhO5Rxg7OUnLY-k4YDbJVvi0OzfwgFMZs08s9an84yUHneCVgYl32xqjs5yDcav1OmYAvMX6oVTcKbPLYNqxRGhe0c8CSIZG07iR57geimpJ8C3i7C-hBjY0noZsPXNnBpw-pRosO0_BU70RKYrIVJhPSzz36GHv_Bj_', 'width': 4032}], 'place_id': 'ChIJgx3vqTld1moRkleFiV2zL9I', 'plus_code': {'compound_code': '5WWW+5X Melbourne, Victoria, Australia', 'global_code': '4RJ65WWW+5X'}, 'rating': 0, 'reference': 'ChIJgx3vqTld1moRkleFiV2zL9I', 'scope': 'GOOGLE', 'types': ['point_of_interest', 'establishment'], 'user_ratings_total': 0, 'vicinity': '552 Victoria St, Melbourne'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': -37.8180822, 'lng': 144.964023}, 'viewport': {'northeast': {'lat': -37.81687442010728, 'lng': 144.9653580298927}, 'southwest': {'lat': -37.81957407989272, 'lng': 144.9626583701072}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png', 'icon_background_color': '#7B9EB0', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet', 'name': 'Electric Vehicle Charging Station', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111882875713557824526">Juan L Rodríguez</a>'], 'photo_reference': 'AelY_CvbcPC3GanA5OFX2Ylhtr5zVpdub5NFmOsLwNYeqPge89Y3GewQsjTR3y0OzqfA-4Eghska5mjmaoR4aZmW_ogbMM4JfnIn4fYHOmDQ9gdcNwMczSXKxJJ4122HZ0bGPrLYBTOfXGIRVCuuOhbaI7A5fNTX-ywieSlV2e8YzZkVtXgL', 'width': 4032}], 'place_id': 'ChIJBYV8JK9D1moRlPVgFFwczg4', 'plus_code': {'compound_code': '5XJ7+QJ Melbourne, Victoria, Australia', 'global_code': '4RJ65XJ7+QJ'}, 'rating': 0, 'reference': 'ChIJBYV8JK9D1moRlPVgFFwczg4', 'scope': 'GOOGLE', 'types': ['point_of_interest', 'establishment'], 'user_ratings_total': 0, 'vicinity': '300 Flinders St, Melbourne'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': -37.8022978, 'lng': 144.9671405}, 'viewport': {'northeast': {'lat': -37.80089207010727, 'lng': 144.9683686798927}, 'southwest': {'lat': -37.80359172989272, 'lng': 144.9656690201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png', 'icon_background_color': '#7B9EB0', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet', 'name': 'Exploren Charging Station', 'opening_hours': {'open_now': Tr ...

# %%
import folium

# Create a map centered around the test location
map_center = [test_location[0], test_location[1]]
map = folium.Map(location=map_center, zoom_start=13)

# Add markers for each charging station
for station in nearby_stations['results']:
    lat = station['geometry']['location']['lat']
    lng = station['geometry']['location']['lng']
    name = station['name']
    folium.Marker([lat, lng], popup=name).add_to(map)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_43226b38de506cc8fe90f8712db748cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_43226b38de506cc8fe90f8712db748cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_43226b38de506cc8fe90f8712db748cb = L.map(
#                 &quot;map_43226b38de506cc8fe90f8712db748cb&quot;,
#                 {
#                     center: [-37.8136276, 144.9630576],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6718bc41ad18de4780b953f2002e76b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c6718bc41ad18de4780b953f2002e76b.addTo(map_43226b38de506cc8fe90f8712db748cb);
#
#
#             var marker_39412d5d907dcadc2fca7bacbeabe36e = L.marker(
#                 [-37.8044708, 144.9932696],
#                 {}
#             ).addTo(map_43226b38de506cc8fe90f8712db748cb);
#
#
#         var popup_9d5fbfd96ae153584f4bc068b8cd7c4e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c23bfcfae6a04ee8a6a542f6f452d4d = $(`&lt;div id=&quot;html_0c23bfcfae6a04ee8a6a542f6f452d4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Evie Charging Station&lt;/div&gt;`)[0];
#                 popup_9d5fbfd96ae153584f4bc068b8cd7c4e.setContent(html_0c23bfcfae6a04ee8a6a542f6f452d4d);
#
#
#
#         marker_39412d5d907dcadc2fca7bacbeabe36e.bindPopup(popup_9d5fbfd96ae153584f4bc068b8cd7c4e)
#         ;
#
#
#
#
#             var marker_41b59eaf81541730b386c507171e1379 = L.marker(
#                 [-37.8321121, 144.9957142],
#                 {}
#             ).addTo(map_43226b38de506cc8fe90f8712db748cb);
#
#
#         var popup_be88152848adb5074afa085af29cc263 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_58d314ba99fc4ba999635af4cb7c7bde = $(`&lt;div id=&quot;html_58d314ba99fc4ba999635af4cb7c7bde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tesla Supercharger&lt;/div&gt;`)[0];
#                 popup_be88152848adb5074afa085af29cc263.setContent(html_58d314ba99fc4ba999635af4cb7c7bde);
#
#
#
#         marker_41b59eaf81541730b386c507171e1379.bindPopup(popup_be88152848adb5074afa085af29cc263)
#         ;
#
#
#
#
#             var marker_381b31ae4c3e3caa3caaeab92879ba61 = L.marker(
#                 [-37.7726351, 144.9152875],
#                 {}
#             ).addTo(map_43226b38de506cc8fe90f8712db748cb);
#
#
#         var popup_62e463a659d9db8046c3a00b3cb6d109 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f42e5faffb3cf2080ab0d1f909631341 = $(`&lt;div id=&quot;html_f42e5faffb3cf2080ab0d1f909631341&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Evie Charging Station&lt;/div&gt;`)[0];
#                 popup_62e463a659d9db8046c3a00b3cb6d109.setContent(html_f42e5faffb3cf2080ab0d1f909631341);
#
#
#
#         marker_381b31ae4c3e3caa3caaeab92879ba61.bindPopup(popup_62e463a659d9db8046c3a00b3cb6d109)
#         ;
#
#
#
#
#             var marker_7174cc89dee2b80667587af4d63dc9eb = L.marker(
#                 [-37.8128515, 145.0100908],
#                 {}
#             ).addTo(map_43226b38de506cc8fe90f8712db748cb);
#
#
#         var popup_5caf76944718c321631b00eccc35ca6f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_28dbd7cf0a07da2b0e294c76a8d423ef = $(`&lt;div id=&quot;html_28dbd7cf0a07da2b0e294c76a8d423ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chargefox Charging Station&lt;/div&gt;`)[0];
#                 popup_5caf76944718c321631b00eccc35ca6f.setContent(html_28dbd7cf0a07da2b0e294c76a8d423ef);
#
#
#
#         marker_7174cc89dee2b80667587af4d63dc9eb.bindPopup(popup_5caf76944718c321631b00eccc35ca6f)
#         ;
#
#
#
#
#             var marker_1cce748d2344861b5009c205b3242d62 = L.marker(
#                 [-37.8562479, 144.9932219],
#                 {}
#             ).addTo(map_43226b38de506cc8fe90f8712db748cb);
#
#
#         var popup_c56d5aae43a05f094fc0ccb7f1871462 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1f9b55517a59410c9179158b6d509d89 = $(`&lt;div id=&quot;html_1f9b55517a59410c9179158b6d509d89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Evie Charging Station&lt;/div&gt;`)[0];
#                 popup_c56d5aae43a05f094fc0ccb7f1871462.setContent(html_1f9b55517a59410c9179158b6d509d89);
#
#
#
#         marker_1cce748d2344861b5009c205b3242d62.bindPopup(popup_c56d5aae43a05f094fc0ccb7f1871462)
#         ;
#
#
#
#
#             var marker_146dd7f693c96c4c6a40422c2d4d71cc = L.marker(
#                 [-37.8320728, 144.919451],

# %%
import googlemaps
import folium
from googlemaps.convert import decode_polyline
import time

# Initialize the Google Maps client with your API key
gmaps = googlemaps.Client(key='AIzaSyA0Tje6iD8W3PKTMxH7au2NlZAWr0y1xjw')

# Step 1: Manually enter two locations
origin = input("Enter the starting location: ")
destination = input("Enter the destination location: ")

# Step 2: Get directions between the two locations
directions_result = gmaps.directions(origin, destination, mode="driving")

# Extract the route polyline
route_polyline = directions_result[0]['overview_polyline']['points']

# Decode the polyline to get a list of latitude/longitude pairs
route_coords = decode_polyline(route_polyline)

# Step 3: Find EV charging stations along the route
ev_charging_stations = []
buffer_distance = 5000  # 5 km radius for nearby places

for coord in route_coords:
    nearby_stations = gmaps.places_nearby(location=(coord['lat'], coord['lng']),
                                          radius=buffer_distance,
                                          keyword='EV charging')
    ev_charging_stations.extend(nearby_stations['results'])

    # Handle pagination if there are more results
    while 'next_page_token' in nearby_stations:
        time.sleep(2)  # Delay to handle API rate limiting
        nearby_stations = gmaps.places_nearby(location=(coord['lat'], coord['lng']),
                                              radius=buffer_distance,
                                              keyword='EV charging',
                                              page_token=nearby_stations['next_page_token'])
        ev_charging_stations.extend(nearby_stations['results'])

# Remove duplicates by place_id
unique_ev_charging_stations = {station['place_id']: station for station in ev_charging_stations}.values()

# Step 4: Visualize the route and EV charging stations on a map
map_center = [(route_coords[0]['lat'] + route_coords[-1]['lat']) / 2,
              (route_coords[0]['lng'] + route_coords[-1]['lng']) / 2]
map = folium.Map(location=map_center, zoom_start=10)

# Add the route to the map
folium.PolyLine([(point['lat'], point['lng']) for point in route_coords], color="blue", weight=2.5).add_to(map)

# Add EV charging stations to the map
for station in unique_ev_charging_stations:
    lat = station['geometry']['location']['lat']
    lng = station['geometry']['location']['lng']
    name = station['name']
    folium.Marker([lat, lng], popup=name).add_to(map)

# Display the map in the notebook
map
# Out:
# Enter the starting location: Melbourne
# Enter the destination location: sydney
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b6a8bc53d088cd21dbb7a81d65a8367 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b6a8bc53d088cd21dbb7a81d65a8367&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b6a8bc53d088cd21dbb7a81d65a8367 = L.map(
#                 &quot;map_0b6a8bc53d088cd21dbb7a81d65a8367&quot;,
#                 {
#                     center: [-35.84131000000001, 148.08613000000003],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_caf0535a9c9b62cd5d37f293a043d733 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_caf0535a9c9b62cd5d37f293a043d733.addTo(map_0b6a8bc53d088cd21dbb7a81d65a8367);
#
#
#             var poly_line_2a24a8394ab6e03e01a57126851d2927 = L.polyline(
#                 [[-37.81365, 144.96299000000002], [-37.807410000000004, 144.95089000000002], [-37.806050000000006, 144.93968], [-37.79515, 144.93593], [-37.75694, 144.93765000000002], [-37.742070000000005, 144.9323], [-37.73274, 144.9165], [-37.734080000000006, 144.89292], [-37.717360000000006, 144.89236000000002], [-37.704980000000006, 144.88754], [-37.69348, 144.90609], [-37.68992, 144.9788], [-37.65963, 144.98694], [-37.63295, 144.99358], [-37.6088, 144.98280000000003], [-37.59741, 144.95314000000002], [-37.57224, 144.94061000000002], [-37.508770000000005, 144.95029000000002], [-37.485200000000006, 144.96771], [-37.46141, 144.97159000000002], [-37.426970000000004, 144.98597], [-37.40007000000001, 145.01876000000001], [-37.378240